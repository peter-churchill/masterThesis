# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import statistics
import math
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import pandas as pd
import matplotlib as mpl
from sklearn.cluster import KMeans
#import dofitPython_functions as LogFit 
from scipy.stats import normaltest
from scipy.stats import kruskal
from scipy.stats import shapiro

# %%
ECearth_ds = xr.open_dataset('/share/pech2273/ECEarthProcessed.nc')
NorESM_ds = xr.open_dataset('/share/pech2273/NorESMProcessed.nc')
ECMassFrac_ds = xr.open_dataset("/share/pech2273/ECMassFrac.nc")
NorMassFrac_ds = xr.open_dataset("/share/pech2273/NorMassFrac.nc")
ECMassFrac_ds = ECMassFrac_ds.reindex(time = ECearth_ds['time'])
ECMassFracGroups = ECMassFrac_ds.groupby(ECearth_ds['label'])
NorMassFracGroups = NorMassFrac_ds.groupby(NorESM_ds['label'])
ECearthGroups = ECearth_ds.groupby(ECearth_ds['label'])
NorGroups = NorESM_ds.groupby(NorESM_ds['label'])

# %%
plt.figure(figsize =(7,7))

(ECearth_ds['Tot_dis']*1E-6).isel(lev = 0).mean('time').plot(xscale = 'log', xlim = [1,1000], label = 'Mean', color = 'black')


plt.fill_between(ECearth_ds['D'],(ECearth_ds['Tot_dis']*1E-6).isel(lev = 0).quantile(0.75, dim='time'),(ECearth_ds['Tot_dis']*1E-6).isel(lev = 0).quantile(0.25, dim='time'),color='gray', alpha=0.5, label = 'Interquartile Range')
plt.xlabel('Diameter (nm)')
plt.ylabel('dNdlogD ($cm^{-3}$)')
plt.title('EC-Earth Mean Aerosol Distribution for the First Layer')
plt.legend()

# %%
plt.figure(figsize =(7,7))

(ECearth_ds['Tot_dis']*1E-6).isel(lev = 1).mean('time').plot(xscale = 'log', xlim = [1,1000], label = 'Mean', color = 'black')


plt.fill_between(ECearth_ds['D'],(ECearth_ds['Tot_dis']*1E-6).isel(lev = 1).quantile(0.75, dim='time'),(ECearth_ds['Tot_dis']*1E-6).isel(lev = 1).quantile(0.25, dim='time'),color='gray', alpha=0.5, label = 'Interquartile Range')
plt.xlabel('Diameter (nm)')
plt.ylabel('dNdlogD ($cm^{-3}$)')
plt.title('EC-Earth Mean Aerosol Distribution for the Second Layer')
plt.legend()

# %%
plt.figure(figsize =(7,7))

NorESM_ds['Tot_dis'].isel(lev = -1).mean('time').plot(xscale = 'log', xlim = [1,1000], label = 'Mean', color = 'black')


plt.fill_between(NorESM_ds['D'],NorESM_ds['Tot_dis'].isel(lev = -1).quantile(0.75, dim='time'),NorESM_ds['Tot_dis'].isel(lev = -1).quantile(0.25, dim='time'),color='gray', alpha=0.5, label = 'Interquartile Range')
plt.xlabel('Diameter (nm)')
plt.ylabel('dNdlogD ($cm^{-3}$)')
plt.title('NorESM Mean Aerosol Distribution for the First Layer')
plt.legend()

# %%
fig = plt.figure(figsize = (10,7))
for i in range(1,7):
    plt.subplot(2,3,i)
    plt.title(f' Cluster {i}')
    plt.pie([ECMassFracGroups[i-1]['BCMassFrac'].dropna('time').isel(lev = 0).mean('time'),\
             ECMassFracGroups[i-1]['OAMassFrac'].dropna('time').isel(lev = 0).mean('time'),\
             ECMassFracGroups[i-1]['SO4MassFrac'].dropna('time').isel(lev = 0).mean('time'),\
             ECMassFracGroups[i-1]['SeasaltMassFrac'].dropna('time').isel(lev = 0).mean('time'),\
             ECMassFracGroups[i-1]['DustMassFrac'].dropna('time').isel(lev = 0).mean('time')],\
             colors=['black', 'green','red','blue','purple'], labels = ['BC','OA','AS','Seasalt', 'Dust'])
plt.show()

# %%
fig = plt.figure(figsize = (8,7))
for i in range(1,5):
    plt.subplot(2,2,i)
    plt.title(f' Cluster {i}')
    plt.pie([NorMassFracGroups[i-1]['BCMassFrac'].dropna('time').isel(lev = -1).mean('time'),\
             NorMassFracGroups[i-1]['OAMassFrac'].dropna('time').isel(lev = -1).mean('time'),\
             NorMassFracGroups[i-1]['SO4MassFrac'].dropna('time').isel(lev = -1).mean('time'),\
             NorMassFracGroups[i-1]['SeasaltMassFrac'].dropna('time').isel(lev = -1).mean('time'),\
             NorMassFracGroups[i-1]['DustMassFrac'].dropna('time').isel(lev = -1).mean('time')],\
             colors=['black', 'green','red','blue','purple'], labels = ['BC','OA','AS','Seasalt', 'Dust'])
plt.show()

# %%
NorESM_ds['time_of_day'] = NorESM_ds['time.hour'] 
NorESM_ds['day_of_year'] = NorESM_ds['time.dayofyear'] 
for i in range(4):
    plt.subplot(2,2,i+1)
    plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==i, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==i, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')

# %%
ECearth_ds['time_of_day'] = ECearth_ds['time.hour'] 
ECearth_ds['day_of_year'] = ECearth_ds['time.dayofyear'] 

plt.subplot(2,3,1)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==0, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==0, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')
plt.subplot(2,3,2)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==1, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==1, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')
plt.subplot(2,3,3)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==2, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==2, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')
plt.subplot(2,3,4)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==3, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==3, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')
plt.subplot(2,3,5)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==4, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==4, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')
plt.subplot(2,3,6)
plt.hist2d(ECearth_ds['day_of_year'].where(ECearth_ds['label'] ==5, drop = 'true'), ECearth_ds['time_of_day'].where(ECearth_ds['label'] ==5, drop = 'true'), bins = [75,8], density = 'true', cmap = 'Greys')

plt.show()
