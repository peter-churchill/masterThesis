# %%
import PeterChurchillFunctions as Function

# %%
NorPath = "/share/sabl0586/all_stations_NorESM_OsloAero_prcp2szdst_f19_f19_noresmv211_corr_ilevall_levs_4Peter.nc"
ECPath = "/share/sabl0586/all_stations_EC-Earth_PRCP2SZDST_ilevall_levs_4Peter.nc"
station='SMR-II'
VarList = ['FREQL', 'AWNC', 'WSUB', 'T']
ifs_vars = ['var130','var54','var131','var132','var20','var21','var22','var248']
ifs_vars_names = ['temp','pres','U','V','CDNC','re_liq','Liquid_Cloud_time','Cloud_Frac']

# %%
#Nor_ds = Function.NorESMExtract(NorPath, station, VarList)
EC_ds = Function.ECearthExtract(ECPath, station, ifs_vars, ifs_vars_names)
