# %%
import xarray as xr
import matplotlib.pyplot as plt
import numpy as np
import statistics
import math
import seaborn as sns
from scipy import stats
import statsmodels.api as sm
import pandas as pd

# %%
xrdsNorESMall_levs = xr.open_dataset("/share/sabl0586/all_stations_NorESM_OsloAero_prcp2szdst_f19_f19_noresmv211_corr_ilevall_levs_4Peter.nc")
SMRNorlevs =  xrdsNorESMall_levs.sel(station='SMR-II')
lev = SMRNorlevs.indexes['lev']
time = SMRNorlevs.indexes['time']

# %%
dsECEearthallevs=xr.open_dataset("/share/sabl0586/all_stations_EC-Earth_PRCP2SZDST_ilevall_levs_4Peter.nc")
SMREClevs = dsECEearthallevs.sel(station = 'SMR-II')
EClev = SMREClevs.indexes['lev']
EClevifs = SMREClevs.indexes['lev_ifs']
ECtime = SMREClevs.indexes['time']

# %%
CloudBaseHeight = xr.DataArray(dims = ['time'], coords = dict( time = ECtime)) 
CloudBaseTemp = xr.DataArray(dims = ['time'], coords = dict( time = ECtime))

def FindCloudbaseNor(Data):
    for t in range (0, len(Data['FREQL'])):
        a = Data['FREQL'].isel(time = t)
        a = a.to_numpy()
        a = np.flip(a)
        result= []
        for i in range(0,len(a)):
            if a[i]>0.5: 
                result.append(i) 
        if len(result)>0:
            CloudBaseHeight[t] = lev[31-result[0]]
            CloudBaseTemp[t] = Data['T'].sel(lev=lev[31-result[0]]).isel(time =t)
        else:
            CloudBaseHeight[t] = np.nan
            CloudBaseTemp[t] = np.nan
    return CloudBaseHeight, CloudBaseTemp

# %%
ECCloudBaseHeight = xr.DataArray(dims = ['time'], coords = dict( time = ECtime)) 
ECCloudBaseTemp = xr.DataArray(dims = ['time'], coords = dict( time = ECtime))

def FindCloudbaseEC(Data):
    for t in range (0, len(Data['var248'].sel(lev = 1))):
        a = Data['var248'].sel(lev = 1).isel(time = t)
        a = a.to_numpy()
        a = np.flip(a)
        result= []
        for i in range(0,len(a)):
            if a[i]>0.5: 
                result.append(i) 
        if len(result)>0:
            ECCloudBaseHeight[t] = EClevifs[90-result[0]]
            ECCloudBaseTemp[t] = SMREClevs['var130'].sel(lev_ifs=EClevifs[90-result[0]], lev = 1).isel(time =t)
        else:
            ECCloudBaseHeight[t] = 'nan'
            ECCloudBaseTemp[t] = 'nan'
    return ECCloudBaseHeight, ECCloudBaseTemp

# %%
#len(SMREClevs['var248'].sel(lev = 1))
len(ECCloudBaseTemp)
# Out:
# 60393

# %%
FindCloudbaseEC(SMREClevs)
# Out:
# (<xarray.DataArray (time: 60393)> Size: 483kB
#  array([nan, nan, nan, ..., nan, nan, nan])
#  Coordinates:
#    * time     (time) datetime64[ns] 483kB 2012-01-01 ... 2019-01-01,
#  <xarray.DataArray (time: 60393)> Size: 483kB
#  array([nan, nan, nan, ..., nan, nan, nan])
#  Coordinates:
#    * time     (time) datetime64[ns] 483kB 2012-01-01 ... 2019-01-01)

# %%
plt.hist(ECCloudBaseHeight)
# Out:
# (array([  81.,  388., 1116.,  930.,  708.,  708., 1262., 1734., 2882.,
#         4080.]),
#  array([47. , 51.4, 55.8, 60.2, 64.6, 69. , 73.4, 77.8, 82.2, 86.6, 91. ]),
#  <BarContainer object of 10 artists>)

# %%
ECCloudBaseTemp[300]
# Out:
# <xarray.DataArray ()> Size: 8B
# array(263.14431763)
# Coordinates:
#     time     datetime64[ns] 8B 2012-01-13T12:00:00

# %%
plt.plot(ECCloudBaseTemp, marker='.')

# %%
for t in range (0, len(SMRNorlevs['FREQL'])):
    a = SMRNorlevs['FREQL'].isel(time = t)
    a = a.to_numpy()
    a = np.flip(a)
    result= []
    for i in range(0,len(a)):
        if a[i]>0.5: 
            result.append(i) 
    if len(result)>0:
        CloudBaseHeight[t] = lev[31-result[0]]
        CloudBaseTemp[t] = SMRNorlevs['T'].sel(lev=lev[31-result[0]]).isel(time =t)
    else:
        CloudBaseHeight[t] = 'nan'
        CloudBaseTemp[t] = 'nan'

# %%
plt.scatter(CloudBaseTemp, CloudBaseHeight)
plt.ylim([1000,1])
# Out:
# (1000.0, 1.0)

# %%
a = SMREClevs['var248'].isel(time=300).sel(lev = 1).to_numpy()
a = np.flip(a)
result= []
for i in range(0,len(a)):
    if a[i]>0.5: 
            result.append(i) 
    if len(result)>0:
        TestBaseHeight = EClevifs[90-result[0]]
        TestBaseTemp = SMREClevs['var130'].sel(lev_ifs=EClevifs[90-result[0]], lev = 1).isel(time =300)
    else:
        TestBaseHeight = 'nan'
        TestBaseTemp = 'nan'
print(TestBaseTemp)
# Out:
# <xarray.DataArray 'var130' ()> Size: 4B
# [1 values with dtype=float32]
# Coordinates:
#     lev        float64 8B 1.0
#     station    <U8 32B 'SMR-II'
#     time       datetime64[ns] 8B 2012-01-13T12:00:00
#     time_orig  datetime64[ns] 8B ...
#     lev_ifs    float64 8B 84.0
# Attributes:
#     table:             128
#     CDI_grid_type:     gaussian
#     CDI_grid_num_LPE:  128

# %%
SMREClevs['var130'].sel(lev_ifs=EClevifs[90-7], lev = 1).isel(time =300).to_numpy()
# Out:
# array(263.14432, dtype=float32)

# %%
SMRNorlevs['FREQL'].isel(time=1900).plot(y='lev', ylim=[1000,1], xlim = [0,1])

# %%
np.nanmin(ECCloudBaseHeight)
for i in range(0, len(ECCloudBaseHeight)):
    if ECCloudBaseHeight[i] == np.nanmin(ECCloudBaseHeight):
        print(i)
# Out:
# 19170
# 44406

# %%
t = 44406
SMREClevs['var248'].isel(time=t,lev=1).plot(y='lev_ifs', ylim=[90,1], xlim = [0,1])
plt.axhline(ECCloudBaseHeight[t])
plt.axvline(.5)
